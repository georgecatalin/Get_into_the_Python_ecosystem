# %% [markdown]
# # Functions

# %% [markdown]
# ## lambda functions

# %%
(lambda x: x+3)(1978)
# Out:
# 1981

# %%
myList = ({'num':3},{'num':2},{'num':1})
sorted(myList, key=lambda x:x['num'])
# Out:
# [{'num': 1}, {'num': 2}, {'num': 3}]
